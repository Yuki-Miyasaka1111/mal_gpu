# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# 2024-10-03 13:07:31.014305: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-03 13:07:31.925216: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-10-03 13:07:37.468946: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /device:GPU:0 with 6382 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:07:00.0, compute capability: 8.0
# 2024-10-03 13:07:37.471663: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /device:GPU:1 with 6382 MB memory:  -> device: 1, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:0f:00.0, compute capability: 8.0
# 2024-10-03 13:07:37.473816: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /device:GPU:2 with 38380 MB memory:  -> device: 2, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:47:00.0, compute capability: 8.0
# 2024-10-03 13:07:37.475992: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /device:GPU:3 with 38380 MB memory:  -> device: 3, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:4e:00.0, compute capability: 8.0
# 2024-10-03 13:07:37.478106: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /device:GPU:4 with 38380 MB memory:  -> device: 4, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:87:00.0, compute capability: 8.0
# 2024-10-03 13:07:37.480224: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /device:GPU:5 with 38380 MB memory:  -> device: 5, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:90:00.0, compute capability: 8.0
# 2024-10-03 13:07:37.482514: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /device:GPU:6 with 11484 MB memory:  -> device: 6, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:b7:00.0, compute capability: 8.0
# 2024-10-03 13:07:37.485085: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /device:GPU:7 with 11484 MB memory:  -> device: 7, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:bd:00.0, compute capability: 8.0
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 16675935366945566429
#  xla_global_id: -1,
#  name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 6692798464
#  locality {
#    bus_id: 4
#    numa_node: 3
#    links {
#      link {
#        device_id: 1
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 2
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 3
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 4
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 5
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 6
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 7
#        type: "StreamExecutor"
#        strength: 1
#      }
#    }
#  }
#  incarnation: 11040864443989442711
#  physical_device_desc: "device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:07:00.0, compute capability: 8.0"
#  xla_global_id: 416903419,
#  name: "/device:GPU:1"
#  device_type: "GPU"
#  memory_limit: 6692798464
#  locality {
#    bus_id: 4
#    numa_node: 3
#    links {
#      link {
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 2
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 3
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 4
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 5
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 6
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 7
#        type: "StreamExecutor"
#        strength: 1
#      }
#    }
#  }
#  incarnation: 233745238019637520
#  physical_device_desc: "device: 1, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:0f:00.0, compute capability: 8.0"
#  xla_global_id: 2144165316,
#  name: "/device:GPU:2"
#  device_type: "GPU"
#  memory_limit: 40244674560
#  locality {
#    bus_id: 2
#    numa_node: 1
#    links {
#      link {
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 1
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 3
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 4
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 5
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 6
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 7
#        type: "StreamExecutor"
#        strength: 1
#      }
#    }
#  }
#  incarnation: 787823266222589189
#  physical_device_desc: "device: 2, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:47:00.0, compute capability: 8.0"
#  xla_global_id: 1651660799,
#  name: "/device:GPU:3"
#  device_type: "GPU"
#  memory_limit: 40244674560
#  locality {
#    bus_id: 2
#    numa_node: 1
#    links {
#      link {
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 1
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 2
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 4
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 5
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 6
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 7
#        type: "StreamExecutor"
#        strength: 1
#      }
#    }
#  }
#  incarnation: 13987024302418858299
#  physical_device_desc: "device: 3, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:4e:00.0, compute capability: 8.0"
#  xla_global_id: 878896533,
#  name: "/device:GPU:4"
#  device_type: "GPU"
#  memory_limit: 40244674560
#  locality {
#    bus_id: 8
#    numa_node: 7
#    links {
#      link {
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 1
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 2
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 3
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 5
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 6
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 7
#        type: "StreamExecutor"
#        strength: 1
#      }
#    }
#  }
#  incarnation: 1905566164249402713
#  physical_device_desc: "device: 4, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:87:00.0, compute capability: 8.0"
#  xla_global_id: 615190153,
#  name: "/device:GPU:5"
#  device_type: "GPU"
#  memory_limit: 40244674560
#  locality {
#    bus_id: 8
#    numa_node: 7
#    links {
#      link {
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 1
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 2
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 3
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 4
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 6
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 7
#        type: "StreamExecutor"
#        strength: 1
#      }
#    }
#  }
#  incarnation: 16023655260246288570
#  physical_device_desc: "device: 5, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:90:00.0, compute capability: 8.0"
#  xla_global_id: 1769886423,
#  name: "/device:GPU:6"
#  device_type: "GPU"
#  memory_limit: 12042633216
#  locality {
#    bus_id: 6
#    numa_node: 5
#    links {
#      link {
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 1
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 2
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 3
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 4
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 5
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 7
#        type: "StreamExecutor"
#        strength: 1
#      }
#    }
#  }
#  incarnation: 10708094590090976588
#  physical_device_desc: "device: 6, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:b7:00.0, compute capability: 8.0"
#  xla_global_id: 893286608,
#  name: "/device:GPU:7"
#  device_type: "GPU"
#  memory_limit: 12042633216
#  locality {
#    bus_id: 6
#    numa_node: 5
#    links {
#      link {
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 1
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 2
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 3
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 4
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 5
#        type: "StreamExecutor"
#        strength: 1
#      }
#      link {
#        device_id: 6
#        type: "StreamExecutor"
#        strength: 1
#      }
#    }
#  }
#  incarnation: 7600513692535622795
#  physical_device_desc: "device: 7, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:bd:00.0, compute capability: 8.0"
#  xla_global_id: 2099794689]

# %%
import torch

print(torch.cuda.is_available())
# Out:
# True
